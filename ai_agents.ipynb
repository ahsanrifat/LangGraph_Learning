# %% [markdown]
# ## Loading the LLM

# %%
from dotenv import load_dotenv
from typing import TypedDict, List, Union

# Lang Graph Imports
from langgraph.graph import StateGraph, START, END

# Langchin Imports
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, AIMessage

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",  # Or "gemini-1.5-pro", etc.
    temperature=0,  # For more deterministic responses
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# ### Basic AI Agent 1

# %%
class AgentState(TypedDict):
    messages: List[HumanMessage]


def process(state: AgentState) -> AgentState:
    response = llm.invoke(state["messages"])
    print(response.content)
    return state


graph = StateGraph(AgentState)
graph.add_node("process_node", process)
graph.add_edge(START, "process_node")
graph.add_edge("process_node", END)
agent = graph.compile()

user_input = input("Enter your message: ")
agent.invoke({"messages": [HumanMessage(content=user_input)]})
# Out:
# /Users/rifat/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:1568: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:192, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     191 try:
# --> 192     return generation_method(**kwargs)
#     193 # Do not retry for these errors.
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:868, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     867 # Send the request.
# --> 868 response = rpc(
#     869     request,
#     870     retry=retry,
#     871     timeout=timeout,
#     872     metadata=metadata,
#     873 )
#     875 # Done; return the response.
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 * GenerateContentRequest.contents: contents is not specified
#
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[35], line 18
#      15 agent = graph.compile()
#      17 user_input = input("Enter your message: ")
# ---> 18 agent.invoke({"messages": [HumanMessage(content=user_input)]})
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/__init__.py:2719, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2716 chunks: list[Union[dict[str, Any], Any]] = []
#    2717 interrupts: list[Interrupt] = []
# -> 2719 for chunk in self.stream(
#    2720     input,
#    2721     config,
#    2722     stream_mode=stream_mode,
#    2723     output_keys=output_keys,
#    2724     interrupt_before=interrupt_before,
#    2725     interrupt_after=interrupt_after,
#    2726     checkpoint_during=checkpoint_during,
#    2727     debug=debug,
#    2728     **kwargs,
#    2729 ):
#    2730     if stream_mode == "values":
#    2731         if (
#    2732             isinstance(chunk, dict)
#    2733             and (ints := chunk.get(INTERRUPT)) is not None
#    2734         ):
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/runner.py:161, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     159 t = tasks[0]
#     160 try:
# --> 161     run_with_retry(
#     162         t,
#     163         retry_policy,
#     164         configurable={
#     165             CONFIG_KEY_CALL: partial(
#     166                 _call,
#     167                 weakref.ref(t),
#     168                 retry=retry_policy,
#     169                 futures=weakref.ref(futures),
#     170                 schedule_task=schedule_task,
#     171                 submit=self.submit,
#     172             ),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/utils/runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/utils/runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[35], line 6, in process(state)
#       5 def process(state: AgentState) -> AgentState:
# ----> 6     response = llm.invoke(state["messages"])
#       7     print(response.content)
#       8     return state
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:1255, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1250     else:
#    1251         raise ValueError(
#    1252             "Tools are already defined." "code_execution tool can't be defined"
#    1253         )
# -> 1255 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:1342, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1316 def _generate(
#    1317     self,
#    1318     messages: List[BaseMessage],
#    (...)
#    1329     **kwargs: Any,
#    1330 ) -> ChatResult:
#    1331     request = self._prepare_request(
#    1332         messages,
#    1333         stop=stop,
#    (...)
#    1340         tool_choice=tool_choice,
#    1341     )
# -> 1342     response: GenerateContentResponse = _chat_with_retry(
#    1343         request=request,
#    1344         **kwargs,
#    1345         generation_method=self.client.generate_content,
#    1346         metadata=self.default_metadata,
#    1347     )
#    1348     return _response_to_result(response)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:210, in _chat_with_retry(generation_method, **kwargs)
#     207     except Exception as e:
#     208         raise e
# --> 210 return _chat_with_retry(**kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:204, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     201         raise ValueError(error_msg)
#     203 except google.api_core.exceptions.InvalidArgument as e:
# --> 204     raise ChatGoogleGenerativeAIError(
#     205         f"Invalid argument provided to Gemini: {e}"
#     206     ) from e
#     207 except Exception as e:
#     208     raise e
#
# ChatGoogleGenerativeAIError: Invalid argument provided to Gemini: 400 * GenerateContentRequest.contents: contents is not specified

# %% [markdown]
# ### Agent 2 (Context)

# %%
class AgentState(TypedDict):
    messages: List[Union[HumanMessage, AIMessage]]


def process(state: AgentState) -> AgentState:
    response = llm.invoke(state["messages"])
    print(response.content)
    state["messages"].append(AIMessage(content=response.content))
    print(f"Current State Messages:{state['messages']}")
    return state


graph2 = StateGraph(AgentState)
graph2.add_node("process_node", process)
graph2.add_edge(START, "process_node")
graph2.add_edge("process_node", END)
agent = graph2.compile()
user_input = input("Enter your message: ")
conversation_history = []
while user_input.lower() != "exit":
    conversation_history.append(HumanMessage(content=user_input))
    result = agent.invoke({"messages": conversation_history})
    # Update conversation_history with the AI response
    conversation_history = result["messages"]

    # Remove oldest pair if more than 3 pairs (6 messages)
    if len(conversation_history) > 6:
        conversation_history = conversation_history[
            2:
        ]  # Remove first pair (2 messages)

    user_input = input("Enter your message: ")
# Out:
# Hi there! How can I help you today?
# Current State Messages:[HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={})]
# There isn't a single "best" country in the world, as it depends entirely on what criteria you prioritize. What one person considers the best, another might not.
#
# However, if you're looking for countries that frequently rank highly in various global indices for quality of life, happiness, economic stability, and social progress, some commonly cited examples include:
#
# *   **Switzerland**
# *   **Canada**
# *   **Norway**
# *   **Sweden**
# *   **New Zealand**
# *   **Finland**
# *   **Denmark**
# *   **Australia**
# *   **Netherlands**
# *   **Iceland**
#
# Again, this is just a selection based on common rankings, and the "best" is subjective.
# Current State Messages:[HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is the best country in the world. just tell me the name nothing else', additional_kwargs={}, response_metadata={}), AIMessage(content='There isn\'t a single "best" country in the world, as it depends entirely on what criteria you prioritize. What one person considers the best, another might not.\n\nHowever, if you\'re looking for countries that frequently rank highly in various global indices for quality of life, happiness, economic stability, and social progress, some commonly cited examples include:\n\n*   **Switzerland**\n*   **Canada**\n*   **Norway**\n*   **Sweden**\n*   **New Zealand**\n*   **Finland**\n*   **Denmark**\n*   **Australia**\n*   **Netherlands**\n*   **Iceland**\n\nAgain, this is just a selection based on common rankings, and the "best" is subjective.', additional_kwargs={}, response_metadata={})]
# There are 50 states in America.
# Current State Messages:[HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is the best country in the world. just tell me the name nothing else', additional_kwargs={}, response_metadata={}), AIMessage(content='There isn\'t a single "best" country in the world, as it depends entirely on what criteria you prioritize. What one person considers the best, another might not.\n\nHowever, if you\'re looking for countries that frequently rank highly in various global indices for quality of life, happiness, economic stability, and social progress, some commonly cited examples include:\n\n*   **Switzerland**\n*   **Canada**\n*   **Norway**\n*   **Sweden**\n*   **New Zealand**\n*   **Finland**\n*   **Denmark**\n*   **Australia**\n*   **Netherlands**\n*   **Iceland**\n\nAgain, this is just a selection based on common rankings, and the "best" is subjective.', additional_kwargs={}, response_metadata={}), HumanMessage(content='what number of states are there in america?', additional_kwargs={}, response_metadata={}), AIMessage(content='There are 50 states in America.', additional_kwargs={}, response_metadata={})]
# California has the highest GDP among U.S. states.
# Current State Messages:[HumanMessage(content='hi', additional_kwargs={}, response_metadata={}), AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is the best country in the world. just tell me the name nothing else', additional_kwargs={}, response_metadata={}), AIMessage(content='There isn\'t a single "best" country in the world, as it depends entirely on what criteria you prioritize. What one person considers the best, another might not.\n\nHowever, if you\'re looking for countries that frequently rank highly in various global indices for quality of life, happiness, economic stability, and social progress, some commonly cited examples include:\n\n*   **Switzerland**\n*   **Canada**\n*   **Norway**\n*   **Sweden**\n*   **New Zealand**\n*   **Finland**\n*   **Denmark**\n*   **Australia**\n*   **Netherlands**\n*   **Iceland**\n\nAgain, this is just a selection based on common rankings, and the "best" is subjective.', additional_kwargs={}, response_metadata={}), HumanMessage(content='what number of states are there in america?', additional_kwargs={}, response_metadata={}), AIMessage(content='There are 50 states in America.', additional_kwargs={}, response_metadata={}), HumanMessage(content='which state has the highest GDP', additional_kwargs={}, response_metadata={}), AIMessage(content='California has the highest GDP among U.S. states.', additional_kwargs={}, response_metadata={})]
# Texas comes in second place for GDP among U.S. states.
# Current State Messages:[HumanMessage(content='what is the best country in the world. just tell me the name nothing else', additional_kwargs={}, response_metadata={}), AIMessage(content='There isn\'t a single "best" country in the world, as it depends entirely on what criteria you prioritize. What one person considers the best, another might not.\n\nHowever, if you\'re looking for countries that frequently rank highly in various global indices for quality of life, happiness, economic stability, and social progress, some commonly cited examples include:\n\n*   **Switzerland**\n*   **Canada**\n*   **Norway**\n*   **Sweden**\n*   **New Zealand**\n*   **Finland**\n*   **Denmark**\n*   **Australia**\n*   **Netherlands**\n*   **Iceland**\n\nAgain, this is just a selection based on common rankings, and the "best" is subjective.', additional_kwargs={}, response_metadata={}), HumanMessage(content='what number of states are there in america?', additional_kwargs={}, response_metadata={}), AIMessage(content='There are 50 states in America.', additional_kwargs={}, response_metadata={}), HumanMessage(content='which state has the highest GDP', additional_kwargs={}, response_metadata={}), AIMessage(content='California has the highest GDP among U.S. states.', additional_kwargs={}, response_metadata={}), HumanMessage(content='what comes in the second place?', additional_kwargs={}, response_metadata={}), AIMessage(content='Texas comes in second place for GDP among U.S. states.', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### Agent : ReAct (Reasoning and Acting Agent)
#
# ![image.png](attachment:image.png)

# %%
from typing import Annotated, Sequence

# Message for providing instructions to LLM
from langchain_core.messages import SystemMessage

# passes data back to LLM after it calls a tool
from langchain_core.messages import ToolMessage

# The foundational class for all message types in LangGraph
from langchain_core.messages import BaseMessage

from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode

# ===== example =======

# Annotated - provides additional context witout affecting the type itself

email = Annotated[str, "This has to be valid email"]

email.__metadata__  ## output ('This has to be valid email',)

# Sequence: To automatically handle the state updates for sequences such as by adding new messages to a chat history
# Reducer: how to merge new data into existing state
# add_messaes is the reducer here. It appends new messages to the existing list of messages in the state.

# ====== Example END ======
# Out:
# ('This has to be valid email',)

# %%
class AgentState(TypedDict):
    # preserve the state by appending. Do not override
    messages: Annotated[Sequence[BaseMessage], add_messages]


@tool
def add(a: int, b: int) -> int:
    """This tool adds two numbers together."""
    return a + b


@tool
def date_tool() -> str:
    """Returns the current date."""
    from datetime import datetime

    return datetime.now().strftime("%Y-%m-%d")


tools = [add, date_tool]

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Stable model with good free tier support
    temperature=0,  # For more deterministic responses
    max_tokens=None,
    timeout=None,
    max_retries=2,
).bind_tools(tools)


def model_call(state: AgentState) -> AgentState:
    system_prompt = SystemMessage(
        content="You are my AI assistant, please answer my query to the best of your ability."
    )
    response = llm.invoke([system_prompt] + state["messages"])
    print(f"Model Response: {response.content}")
    ## response will be appended by reducer function no need to append manually
    return {"messages": response}


def should_continue(state: AgentState) -> str:
    last_message = state["messages"][-1]
    if not last_message.tool_calls:
        return "end"
    return "continue"


def print_stream(stream):
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            message.pretty_print()


graph = StateGraph(AgentState)
graph.add_node("model_call", model_call)
tool_node = ToolNode(tools=tools)
graph.add_node("tool_node", tool_node)
graph.set_entry_point("model_call")

graph.add_conditional_edges(
    "model_call",
    should_continue,
    {
        "continue": "tool_node",
        "end": END,
    },
)
graph.add_edge("tool_node", "model_call")

app = graph.compile()

inputs = {"messages": [("user", "add 3 and 4")]}
print_stream(app.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# add 3 and 4
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash
# Please retry in 35.524419172s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 35
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[49], line 76
#      73 app = graph.compile()
#      75 inputs = {"messages": [("user", "add 3 and 4")]}
# ---> 76 print_stream(app.stream(inputs, stream_mode="values"))
#
# Cell In[49], line 49, in print_stream(stream)
#      48 def print_stream(stream):
# ---> 49     for s in stream:
#      50         message = s["messages"][-1]
#      51         if isinstance(message, tuple):
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/__init__.py:2436, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2434         for task in loop.match_cached_writes():
#    2435             loop.output_writes(task.id, task.writes, cached=True)
# -> 2436         for _ in runner.tick(
#    2437             [t for t in loop.tasks.values() if not t.writes],
#    2438             timeout=self.step_timeout,
#    2439             get_waiter=get_waiter,
#    2440             schedule_task=loop.accept_push,
#    2441         ):
#    2442             # emit output
#    2443             yield from output()
#    2444 # emit output
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/runner.py:161, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     159 t = tasks[0]
#     160 try:
# --> 161     run_with_retry(
#     162         t,
#     163         retry_policy,
#     164         configurable={
#     165             CONFIG_KEY_CALL: partial(
#     166                 _call,
#     167                 weakref.ref(t),
#     168                 retry=retry_policy,
#     169                 futures=weakref.ref(futures),
#     170                 schedule_task=schedule_task,
#     171                 submit=self.submit,
#     172             ),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/utils/runnable.py:623, in RunnableSeq.invoke(self, input, config, **kwargs)
#     621     # run in context
#     622     with set_config_context(config, run) as context:
# --> 623         input = context.run(step.invoke, input, config, **kwargs)
#     624 else:
#     625     input = step.invoke(input, config)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langgraph/utils/runnable.py:377, in RunnableCallable.invoke(self, input, config, **kwargs)
#     375         run_manager.on_chain_end(ret)
#     376 else:
# --> 377     ret = self.func(*args, **kwargs)
#     378 if self.recurse and isinstance(ret, Runnable):
#     379     return ret.invoke(input, config)
#
# Cell In[49], line 35, in model_call(state)
#      31 def model_call(state: AgentState) -> AgentState:
#      32     system_prompt = SystemMessage(
#      33         content="You are my AI assistant, please answer my query to the best of your ability."
#      34     )
# ---> 35     response = llm.invoke([system_prompt] + state["messages"])
#      36     print(f"Model Response: {response.content}")
#      37     ## response will be appended by reducer function no need to append manually
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/runnables/base.py:5431, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5424 @override
#    5425 def invoke(
#    5426     self,
#    (...)
#    5429     **kwargs: Optional[Any],
#    5430 ) -> Output:
# -> 5431     return self.bound.invoke(
#    5432         input,
#    5433         self._merge_configs(config),
#    5434         **{**self.kwargs, **kwargs},
#    5435     )
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:1255, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1250     else:
#    1251         raise ValueError(
#    1252             "Tools are already defined." "code_execution tool can't be defined"
#    1253         )
# -> 1255 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:1342, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1316 def _generate(
#    1317     self,
#    1318     messages: List[BaseMessage],
#    (...)
#    1329     **kwargs: Any,
#    1330 ) -> ChatResult:
#    1331     request = self._prepare_request(
#    1332         messages,
#    1333         stop=stop,
#    (...)
#    1340         tool_choice=tool_choice,
#    1341     )
# -> 1342     response: GenerateContentResponse = _chat_with_retry(
#    1343         request=request,
#    1344         **kwargs,
#    1345         generation_method=self.client.generate_content,
#    1346         metadata=self.default_metadata,
#    1347     )
#    1348     return _response_to_result(response)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:210, in _chat_with_retry(generation_method, **kwargs)
#     207     except Exception as e:
#     208         raise e
# --> 210 return _chat_with_retry(**kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:438, in Future.result(self, timeout)
#     436     raise CancelledError()
#     437 elif self._state == FINISHED:
# --> 438     return self.__get_result()
#     440 self._condition.wait(timeout)
#     442 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:208, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     204     raise ChatGoogleGenerativeAIError(
#     205         f"Invalid argument provided to Gemini: {e}"
#     206     ) from e
#     207 except Exception as e:
# --> 208     raise e
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/langchain_google_genai/chat_models.py:192, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     189 @retry_decorator
#     190 def _chat_with_retry(**kwargs: Any) -> Any:
#     191     try:
# --> 192         return generation_method(**kwargs)
#     193     # Do not retry for these errors.
#     194     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:868, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     865 self._validate_universe_domain()
#     867 # Send the request.
# --> 868 response = rpc(
#     869     request,
#     870     retry=retry,
#     871     timeout=timeout,
#     872     metadata=metadata,
#     873 )
#     875 # Done; return the response.
#     876 return response
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/Documents/Coding/lang_graph_learning/.venv/lib/python3.9/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash
# Please retry in 33.343455708s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 33
# }
# ]
